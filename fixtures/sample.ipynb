# %% [markdown]
# # Notebook Title
#
# This Agent uses a Tool Call in a notebook.
#
# See [Docs](https://example.com/docs).

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# ## Details
#
# Use `inline_code` and keep https://example.com unchanged.
